# %% [markdown]
# # DEMO 3: **Byte-Pair Encoding Tokenization** (encoding & decoding)
# ---

# %% [markdown]
# Demo run of Byte-Pair Encoding Tokenization encoding and decoding process over the TinyStories dataset. This run uses a Macbook Pro 2023, M3 Pro.
#
# The implementation uses a greedy approach for the inference. The greediness provides more efficiency in runtime for the tokenization process; Some studies, such as [Greed is All You Need: An Evaluation of Tokenizer Inference Methods](https://arxiv.org/pdf/2403.01289) (2024), show that greedy inference also yields good results in benchmarks, especially for morphologically-motivated tasks.

# %% [markdown]
# ## **BPETokenizer**
# ---

# %% [markdown]
# Let's instantiate a BPE Tokenizer with the `BPETokenizer` class. We can do it using the vocab and merges files created after running `2_pre_tokenization_training.ipynb`, or from the ones provided in `./sample_data/bpe_tokenizer` (which were produced running that notebook, trained on `TinyStories` train.txt data):

# %%
from pathlib import Path


input_dir = Path("./sample_data/bpe_tokenizer")

# %%
from bpe_transformer.tokenization.bpe_tokenizer import BPETokenizer


bpe = BPETokenizer.from_files(
    vocab_filepath=Path(input_dir / "vocab.pkl"), merges_filepath=Path(input_dir / "merges.pkl")
)

# %%
l_50 = 50 * "="
l_50_2 = 50 * "-"
print(l_50)
print("BPE TOKENIZER")
print(l_50)
print("Vocab:")
print(l_50_2)
print(bpe.vocab)
print(f"\nLength: {len(bpe.vocab)}\n")
print(l_50_2)
print("Merges:")
print(l_50_2)
print(bpe.merges)
print(f"\nLength: {len(bpe.merges)}\n")
print(l_50)
print("\n")
# Out:
# ==================================================
# BPE TOKENIZER
# ==================================================
# Vocab:
# --------------------------------------------------
# {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x8c', 141: b'\x8d', 142: b'\x8e', 143: b'\x8f', 144: b'\x90', 145: b'\x91', 146: b'\x92', 147: b'\x93', 148: b'\x94', 149: b'\x95', 150: b'\x96', 151: b'\x97', 152: b'\x98', 153: b'\x99', 154: b'\x9a', 155: b'\x9b', 156: b'\x9c', 157: b'\x9d', 158: b'\x9e', 159: b'\x9f', 160: b'\xa0', 161: b'\xa1', 162: b'\xa2', 163: b'\xa3', 164: b'\xa4', 165: b'\xa5', 166: b'\xa6', 167: b'\xa7', 168: b'\xa8', 169: b'\xa9', 170: b'\xaa', 171: b'\xab', 172: b'\xac', 173: b'\xad', 174: b'\xae', 175: b'\xaf', 176: b'\xb0', 177: b'\xb1', 178: b'\xb2', 179: b'\xb3', 180: b'\xb4', 181: b'\xb5', 182: b'\xb6', 183: b'\xb7', 184: b'\xb8', 185: b'\xb9', 186: b'\xba', 187: b'\xbb', 188: b'\xbc', 189: b'\xbd', 190: b'\xbe', 191: b'\xbf', 192: b'\xc0', 193: b'\xc1', 194: b'\xc2', 195: b'\xc3', 196: b'\xc4', 197: b'\xc5', 198: b'\xc6', 199: b'\xc7', 200: b'\xc8', 201: b'\xc9', 202: b'\xca', 203: b'\xcb', 204: b'\xcc', 205: b'\xcd', 206: b'\xce', 207: b'\xcf', 208: b'\xd0', 209: b'\xd1', 210: b'\xd2', 211: b'\xd3', 212: b'\xd4', 213: b'\xd5', 214: b'\xd6', 215: b'\xd7', 216: b'\xd8', 217: b'\xd9', 218: b'\xda', 219: b'\xdb', 220: b'\xdc', 221: b'\xdd', 222: b'\xde', 223: b'\xdf', 224: b'\xe0', 225: b'\xe1', 226: b'\xe2', 227: b'\xe3', 228: b'\xe4', 229: b'\xe5', 230: b'\xe6', 231: b'\xe7', 232: b'\xe8', 233: b'\xe9', 234: b'\xea', 235: b'\xeb', 236: b'\xec', 237: b'\xed', 238: b'\xee', 239: b'\xef', 240: b'\xf0', 241: b'\xf1', 242: b'\xf2', 243: b'\xf3', 244: b'\xf4', 245: b'\xf5', 246: b'\xf6', 247: b'\xf7', 248: b'\xf8', 249: b'\xf9', 250: b'\xfa', 251: b'\xfb', 252: b'\xfc', 253: b'\xfd', 254: b'\xfe', 255: b'\xff', 256: b'<|endoftext|>', 257: b' t', 258: b'he', 259: b' a', 260: b' s', 261: b' w', 262: b'nd', 263: b' the', 264: b'ed', 265: b' b', 266: b' to', 267: b' and', 268: b' h', 269: b' f', 270: b'in', 271: b' T', 272: b' wa', 273: b're', 274: b'it', 275: b'ou', 276: b' l', 277: b' d', 278: b' c', 279: b' p', 280: b'ay', 281: b' m', 282: b'er', 283: b' was', 284: b'om', 285: b' The', 286: b' he', 287: b'is', 288: b'ar', 289: b' n', 290: b'im', 291: b'on', 292: b' sa', 293: b'id', 294: b'll', 295: b' ha', 296: b' g', 297: b'at', 298: b' S', 299: b'ing', 300: b'ot', 301: b'en', 302: b'an', 303: b'le', 304: b'or', 305: b'ir', 306: b'am', 307: b'et', 308: b' H', 309: b' it', 310: b' th', 311: b'ig', 312: b' They', 313: b' in', 314: b'il', 315: b' pl', 316: b' He', 317: b' "', 318: b'ow', 319: b'ver', 320: b'ri', 3 ...
#
# Length: 10000
#
# --------------------------------------------------
# Merges:
# --------------------------------------------------
# [(b' ', b't'), (b'h', b'e'), (b' ', b'a'), (b' ', b's'), (b' ', b'w'), (b'n', b'd'), (b' t', b'he'), (b'e', b'd'), (b' ', b'b'), (b' t', b'o'), (b' a', b'nd'), (b' ', b'h'), (b' ', b'f'), (b'i', b'n'), (b' ', b'T'), (b' w', b'a'), (b'r', b'e'), (b'i', b't'), (b'o', b'u'), (b' ', b'l'), (b' ', b'd'), (b' ', b'c'), (b' ', b'p'), (b'a', b'y'), (b' ', b'm'), (b'e', b'r'), (b' wa', b's'), (b'o', b'm'), (b' T', b'he'), (b' ', b'he'), (b'i', b's'), (b'a', b'r'), (b' ', b'n'), (b'i', b'm'), (b'o', b'n'), (b' s', b'a'), (b'i', b'd'), (b'l', b'l'), (b' h', b'a'), (b' ', b'g'), (b'a', b't'), (b' ', b'S'), (b'in', b'g'), (b'o', b't'), (b'e', b'n'), (b'a', b'n'), (b'l', b'e'), (b'o', b'r'), (b'i', b'r'), (b'a', b'm'), (b'e', b't'), (b' ', b'H'), (b' ', b'it'), (b' t', b'h'), (b'i', b'g'), (b' The', b'y'), (b' ', b'in'), (b'i', b'l'), (b' p', b'l'), (b' H', b'e'), (b' ', b'"'), (b'o', b'w'), (b'v', b'er'), (b'r', b'i'), (b'u', b't'), (b' b', b'e'), (b' ', b'u'), (b' sa', b'id'), (b' pl', b'ay'), (b'it', b'h'), (b' d', b'ay'), (b' w', b'ith'), (b'p', b'p'), (b'O', b'n'), (b' ', b'o'), (b' ', b'y'), (b'o', b'o'), (b'k', b'ed'), (b' ', b'r'), (b' he', b'r'), (b'c', b'e'), (b' ', b'I'), (b' S', b'he'), (b'l', b'd'), (b' T', b'im'), (b' h', b'is'), (b' s', b't'), (b'k', b'e'), (b' ', b'e'), (b' b', b'ig'), (b'n', b't'), (b'c', b'k'), (b' y', b'ou'), (b'ver', b'y'), (b's', b't'), (b'v', b'e'), (b'e', b'nd'), (b' ', b'on'), (b'u', b'n'), (b' ha', b'pp'), (b'ri', b'end'), (b' f', b'riend'), (b'a', b'll'), (b'il', b'y'), (b' ', b'L'), (b' the', b'y'), (b' w', b'e'), (b' ha', b'd'), (b' n', b'ot'), (b' l', b'i'), (b' u', b'p'), (b'he', b'r'), (b' wa', b'nt'), (b' o', b'f'), (b'a', b'd'), (b'it', b't'), (b's', b'e'), (b' ', b'B'), (b' d', b'o'), (b' happ', b'y'), (b'en', b't'), (b' ', b'very'), (b' ', b'M'), (b'e', b's'), (b' th', b'at'), (b' sa', b'w'), (b'On', b'e'), (b"'", b's'), (b'ou', b'ld'), (b' m', b'om'), (b' f', b'or'), (b' s', b'h'), (b'itt', b'le'), (b' l', b'ittle'), (b' s', b'o'), (b' s', b'he'), (b'c', b'h'), (b'im', b'e'), (b' n', b'e'), (b' n', b'am'), (b'.', b'"'), (b' t', b'ime'), (b' ', b'k'), (b'ou', b'nd'), (b' the', b're'), (b' nam', b'ed'), (b' s', b'm'), (b' b', b'o'), (b' we', b're'), (b' L', b'ily'), (b' want', b'ed'), (b' b', b'ut'), (b'ou', b't'), (b'T', b'he'), (b' friend', b's'), (b'v', b'ed'), (b'!', b'"'), (b'h', b't'), (b' T', b'om'), (b'ir', b'd'), (b'e', b'l'), (b' b', b'ird'), (b'a', b'l'), (b' a', b'n'), (b'a', b'ke'), (b' to', b'o'), (b'om', b'e'), (b' I', b't'), (b'u', b'g'), (b'id', b'e'), (b' w', b'ent'), (b' w', b'h'), (b' he', b'l'), (b'On', b'ce'), (b' ', b'is'), (b' a', b'll'), (b' hel', b'p'), (b'u', b'e'), (b' l', b'oo'), (b' l', b'o'), (b't', b'er'), (b' ', b'A'), (b' up', b'on'), (b'r', b'y'), (b'o', b're'), (b'i', b'nd'), (b' f', b'un'), (b'g', b'et'), (b' to', b'y'), (b'i', b'll'), (b'am', b'e'), (b' a', b's'), (b' a', b't'), (b'r', b'a'), (b' ', b'j'), (b' d', b'id'), (b'get', b'her'), (b' ', b're'), (b'u', b'r'), (b' s', b'e'), (b' to', b'gether'), (b'a', b'ck'), (b' c', b'at'), (b'l', b'y'), (b' t', b're'), (b'oo', b'd'), (b'i', b'c'), (b't', b'ed'), (b' do', b'g'), (b' c', b'ould'), (b' c', b'an'), (b' the', b'ir'), (b'ar', b'd'), (b'e', b'c'), (b'ar', b'k'), (b' g', b'ir'), (b' play', b'ed'), (b' h', b'im'), (b' b', b'all'), (b'?', b'"'), (b' gir', b'l'), (b'w', b'ay'), (b' r', b'o'), (b' g', b'o'), (b'he', b'd'), (b'm', b'y'), (b' a', b're'), (b' ', b'out'), (b' l', b'e'), (b' f', b'r'), (b'a', b'in'), (b' k', b'n'), (b'he', b'n'), (b' the', b'm'), (b'u', b'm'), (b"'", b't'), (b'a', b'x'), (b' sa', b'd'), (b'u', b'l'), (b' bo', b'y'), (b' tre', b'e'), (b'ot', b'her'), (b' ha', b've'), (b' m', b'an'), (b' c', b'l'), (b' lo', b'ved'), (b' loo', b'ked'), (b'ou', b'g'), (b' f', b'ound'), (b' s', b'p'), (b' st', b'ar'), (b' S', b'ue'), (b'on', b'e'), (b'h', b'ing'), (b' s', b'c'), (b' b', b'ack'), (b'ow', b'n'), (b' M', b'ax'), (b'a', b're'), (b' li', b'ke'), (b'f', b'ul'), (b's', b'ide'), (b' m', b ...
#
# Length: 9743
#
# ==================================================

# %% [markdown]
# ### **Encoding**

# %% [markdown]
# Now that we loaded our vocab, let's try encoding a simple string.

# %%
text = "Hello, I am encoding my text. How are you?"

print(text)
print(len(text))
# Out:
# Hello, I am encoding my text. How are you?
# 42

# %% [markdown]
# Try encoding it based on our vocab:

# %%
encode_text = bpe.encode(text=text)

print(encode_text)
print(len(encode_text))
# Out:
# [1183, 44, 338, 740, 835, 1262, 5686, 622, 799, 983, 46, 2687, 483, 349, 63]
# 15

# %% [markdown]
# After encoding, the length of our text representation reduced from 42 to 15. Let's see our tokens:

# %%
tokens = [bpe.vocab[token] for token in encode_text]
print(tokens)
# Out:
# [b'Hello', b',', b' I', b' am', b' en', b'co', b'ding', b' my', b' te', b'xt', b'.', b' How', b' are', b' you', b'?']

# %% [markdown]
# ### **Decoding**

# %% [markdown]
# Now, let's try decoding the string we just encoded:

# %%
decode_text = bpe.decode(ids=encode_text)

print(decode_text)
print(len(decode_text))

assert decode_text == text
# Out:
# Hello, I am encoding my text. How are you?
# 42

# %% [markdown]
# The decoded text is equivalent to the `text` input string we defined in the beginning.
#
# TODO: iterator for long text chunk encoding.
